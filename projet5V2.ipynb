# %%
import numpy as np
import pandas as pd

# %%
web = pd.read_csv('projet 5/web.csv', delimiter=';')
liaison = pd.read_csv('projet 5/liaison.csv', delimiter=';')
erp = pd.read_csv('projet 5/erp.csv',delimiter=';')

# %%
print('ERP')
print(erp.nunique())
# Out:
# ERP
# product_id        825
# onsale_web          2
# price             381
# stock_quantity    128
# stock_status        2
# dtype: int64

# %%
print('Liaison')
liaison.nunique()
# Out:
# Liaison
# product_id    825
# id_web        734
# dtype: int64

# %%
print('Web')
web.nunique()
# Out:
# Web
# sku                       714
# virtual                     1
# downloadable                1
# rating_count                1
# average_rating              1
# total_sales                41
# tax_status                  1
# tax_class                   0
# post_author                 2
# post_date                 716
# post_date_gmt             716
# post_content                0
# post_title                713
# post_excerpt              679
# post_status                 1
# comment_status              1
# ping_status                 1
# post_password               0
# post_name                 716
# post_modified             589
# post_modified_gmt         589
# post_content_filtered       0
# post_parent                 1
# guid                     1430
# menu_order                  1
# post_type                   2
# post_mime_type              1
# comment_count               1
# dtype: int64

# %%
web.head(10)
# Out:
#                    sku  virtual  ...  post_mime_type  comment_count
# 0  bon-cadeau-25-euros        0  ...             NaN            0.0
# 1                15298        0  ...             NaN            0.0
# 2                15296        0  ...             NaN            0.0
# 3                15300        0  ...             NaN            0.0
# 4                19814        0  ...             NaN            0.0
# 5                19815        0  ...             NaN            0.0
# 6                15303        0  ...             NaN            0.0
# 7                14975        0  ...             NaN            0.0
# 8                16042        0  ...             NaN            0.0
# 9                14980        0  ...             NaN            0.0
#
# [10 rows x 28 columns]

# %%
web = web.drop(['virtual', 'downloadable','rating_count','average_rating'], axis=1)

# %%
web.head()
# Out:
#                    sku  total_sales  ... post_mime_type  comment_count
# 0  bon-cadeau-25-euros         10.0  ...            NaN            0.0
# 1                15298          6.0  ...            NaN            0.0
# 2                15296          0.0  ...            NaN            0.0
# 3                15300          0.0  ...            NaN            0.0
# 4                19814          3.0  ...            NaN            0.0
#
# [5 rows x 24 columns]

# %%
web = web.drop(['tax_class','post_date','post_content','post_status','comment_status'], axis=1)

# %%
web.head()
# Out:
#                    sku  total_sales  ... post_mime_type  comment_count
# 0  bon-cadeau-25-euros         10.0  ...            NaN            0.0
# 1                15298          6.0  ...            NaN            0.0
# 2                15296          0.0  ...            NaN            0.0
# 3                15300          0.0  ...            NaN            0.0
# 4                19814          3.0  ...            NaN            0.0
#
# [5 rows x 19 columns]

# %%
web = web.drop(['comment_count','post_mime_type','menu_order','guid'], axis=1)

# %%
web.head()
# Out:
#                    sku  total_sales  ... post_parent  post_type
# 0  bon-cadeau-25-euros         10.0  ...         0.0    product
# 1                15298          6.0  ...         0.0    product
# 2                15296          0.0  ...         0.0    product
# 3                15300          0.0  ...         0.0    product
# 4                19814          3.0  ...         0.0    product
#
# [5 rows x 15 columns]

# %%
web = web.drop(['post_parent','post_content_filtered','post_modified'], axis=1)

# %%
web.head()
# Out:
#                    sku  total_sales  ...    post_modified_gmt  post_type
# 0  bon-cadeau-25-euros         10.0  ...  2018-06-01 12:13:57    product
# 1                15298          6.0  ...  2019-12-30 08:30:29    product
# 2                15296          0.0  ...  2019-12-21 08:00:17    product
# 3                15300          0.0  ...  2020-06-26 16:15:03    product
# 4                19814          3.0  ...  2020-01-04 15:36:01    product
#
# [5 rows x 12 columns]

# %%
web = web.drop(['ping_status','post_password','post_name','post_date_gmt','post_type','post_excerpt'],axis =1)

# %%
web.head()
# Out:
#                    sku  ...    post_modified_gmt
# 0  bon-cadeau-25-euros  ...  2018-06-01 12:13:57
# 1                15298  ...  2019-12-30 08:30:29
# 2                15296  ...  2019-12-21 08:00:17
# 3                15300  ...  2020-06-26 16:15:03
# 4                19814  ...  2020-01-04 15:36:01
#
# [5 rows x 6 columns]

# %%
type(web)
# Out:
# pandas.core.frame.DataFrame

# %%
liaison.head()
# Out:
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815

# %%
 test = pd.merge(liaison, web, left_on='id_web',right_on='sku', how='left')

# %%
test.head(10)
# Out:
#    product_id  ...    post_modified_gmt
# 0        3847  ...  2019-12-30 08:30:29
# 1        3847  ...  2019-12-30 08:30:29
# 2        3849  ...  2019-12-21 08:00:17
# 3        3849  ...  2019-12-21 08:00:17
# 4        3850  ...  2020-06-26 16:15:03
# 5        3850  ...  2020-06-26 16:15:03
# 6        4032  ...  2020-01-04 15:36:01
# 7        4032  ...  2020-01-04 15:36:01
# 8        4039  ...  2020-01-04 15:36:10
# 9        4039  ...  2020-01-04 15:36:10
#
# [10 rows x 8 columns]

# %%
test.describe()
# Out:
#         product_id  total_sales  post_author
# count  9183.000000  1610.000000  1610.000000
# mean   5963.138517     3.559006     1.998758
# std    1156.595743     8.119252     0.035234
# min    3847.000000     0.000000     1.000000
# 25%    4721.000000     0.000000     2.000000
# 50%    6567.000000     0.000000     2.000000
# 75%    7084.000000     4.000000     2.000000
# max    7338.000000    96.000000     2.000000

# %%
test.drop_duplicates('id_web')
# Out:
#       product_id  ...    post_modified_gmt
# 0           3847  ...  2019-12-30 08:30:29
# 2           3849  ...  2019-12-21 08:00:17
# 4           3850  ...  2020-06-26 16:15:03
# 6           4032  ...  2020-01-04 15:36:01
# 8           4039  ...  2020-01-04 15:36:10
# ...          ...  ...                  ...
# 6794        7023  ...  2020-08-26 15:35:02
# 6796        7025  ...  2020-08-14 16:15:03
# 9178        7247  ...  2020-07-20 15:09:06
# 9180        7329  ...                  NaN
# 9181        7338  ...  2020-08-13 08:45:03
#
# [735 rows x 8 columns]

# %%
test.dropna(inplace=True)

# %%
test = test.drop(['sku','tax_status'], axis=1)

# %%
test
# Out:
#       product_id  ...    post_modified_gmt
# 0           3847  ...  2019-12-30 08:30:29
# 2           3849  ...  2019-12-21 08:00:17
# 4           3850  ...  2020-06-26 16:15:03
# 6           4032  ...  2020-01-04 15:36:01
# 8           4039  ...  2020-01-04 15:36:10
# ...          ...  ...                  ...
# 6452        6930  ...  2020-08-26 15:35:03
# 6794        7023  ...  2020-08-26 15:35:02
# 6796        7025  ...  2020-08-14 16:15:03
# 9178        7247  ...  2020-07-20 15:09:06
# 9181        7338  ...  2020-08-13 08:45:03
#
# [714 rows x 6 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 9181
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         714 non-null    int64
#  1   id_web             714 non-null    object
#  2   total_sales        714 non-null    float64
#  3   post_author        714 non-null    float64
#  4   post_title         714 non-null    object
#  5   post_modified_gmt  714 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 55.2+ KB

# %%
test['product_id'] = test['product_id'].astype(str)
test['post_modified_gmt'] = pd.to_datetime(test['post_modified_gmt'])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 9181
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         714 non-null    object
#  1   id_web             714 non-null    object
#  2   total_sales        714 non-null    float64
#  3   post_author        714 non-null    float64
#  4   post_title         714 non-null    object
#  5   post_modified_gmt  714 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 55.2+ KB

# %%
print('Etude fichier test :')
print(test.describe())
# Out:
# Etude fichier test :
#        total_sales  post_author
# count   714.000000   714.000000
# mean      4.012605     1.998599
# std       8.518183     0.037424
# min       0.000000     1.000000
# 25%       0.000000     2.000000
# 50%       1.000000     2.000000
# 75%       4.000000     2.000000
# max      96.000000     2.000000

# %%
test.nunique()
# Out:
# product_id           714
# id_web               714
# total_sales           41
# post_author            2
# post_title           711
# post_modified_gmt    587
# dtype: int64

# %%
test.isnull().sum()
# Out:
# product_id           0
# id_web               0
# total_sales          0
# post_author          0
# post_title           0
# post_modified_gmt    0
# dtype: int64

# %%
test.head()
# Out:
#   product_id  ...   post_modified_gmt
# 0       3847  ... 2019-12-30 08:30:29
# 2       3849  ... 2019-12-21 08:00:17
# 4       3850  ... 2020-06-26 16:15:03
# 6       4032  ... 2020-01-04 15:36:01
# 8       4039  ... 2020-01-04 15:36:10
#
# [5 rows x 6 columns]

# %% [markdown]
# Est ce que mon tri est suffisant et correct ?
# pas de pertes d'informations significatives ?
# rajouter une colonne CA
# Sum(ca)
# repérer les prix qui sont en dehors de valeurs attendus ? quartiles ? boite à moustache ?
